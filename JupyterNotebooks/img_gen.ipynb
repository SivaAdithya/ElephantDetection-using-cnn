# %%
import cv2
import os
  
cam = cv2.VideoCapture("D:/Study material/sem6/Video Analytics/Jcomp/data/video1.mp4")
  
try:
      
    if not os.path.exists('pictures'):
        os.makedirs('pictures')
  
except OSError:
    print ('Error: Creating directory of data')

currentframe = 0
  
while(True):
      
    # reading from frame
    ret,frame = cam.read()
  
    if ret:
        # if video is still left continue creating images
        name = './pictures/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name)
  
        # writing the extracted images
        cv2.imwrite(name, frame)
  
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    else:
        break
# Out:
# Creating..../pictures/frame0.jpg
# Creating..../pictures/frame1.jpg
# Creating..../pictures/frame2.jpg
# Creating..../pictures/frame3.jpg
# Creating..../pictures/frame4.jpg
# Creating..../pictures/frame5.jpg
# Creating..../pictures/frame6.jpg
# Creating..../pictures/frame7.jpg
# Creating..../pictures/frame8.jpg
# Creating..../pictures/frame9.jpg
# Creating..../pictures/frame10.jpg
# Creating..../pictures/frame11.jpg
# Creating..../pictures/frame12.jpg
# Creating..../pictures/frame13.jpg
# Creating..../pictures/frame14.jpg
# Creating..../pictures/frame15.jpg
# Creating..../pictures/frame16.jpg
# Creating..../pictures/frame17.jpg
# Creating..../pictures/frame18.jpg
# Creating..../pictures/frame19.jpg
# Creating..../pictures/frame20.jpg
# Creating..../pictures/frame21.jpg
# Creating..../pictures/frame22.jpg
# Creating..../pictures/frame23.jpg
# Creating..../pictures/frame24.jpg
# Creating..../pictures/frame25.jpg
# Creating..../pictures/frame26.jpg
# Creating..../pictures/frame27.jpg
# ...

# %%
import cv2
import os
  
cam = cv2.VideoCapture("D:/Study material/sem6/Video Analytics/Jcomp/data/video2.mp4")
  
try:
      
    if not os.path.exists('pictures1'):
        os.makedirs('pictures1')
  
except OSError:
    print ('Error: Creating directory of data')

currentframe = 0
  
while(True):
      
    # reading from frame
    ret,frame = cam.read()
  
    if ret:
        # if video is still left continue creating images
        name = './pictures1/2_frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name)
  
        # writing the extracted images
        cv2.imwrite(name, frame)
  
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    else:
        break
# Out:
# Creating..../pictures1/2_frame0.jpg
# Creating..../pictures1/2_frame1.jpg
# Creating..../pictures1/2_frame2.jpg
# Creating..../pictures1/2_frame3.jpg
# Creating..../pictures1/2_frame4.jpg
# Creating..../pictures1/2_frame5.jpg
# Creating..../pictures1/2_frame6.jpg
# Creating..../pictures1/2_frame7.jpg
# Creating..../pictures1/2_frame8.jpg
# Creating..../pictures1/2_frame9.jpg
# Creating..../pictures1/2_frame10.jpg
# Creating..../pictures1/2_frame11.jpg
# Creating..../pictures1/2_frame12.jpg
# Creating..../pictures1/2_frame13.jpg
# Creating..../pictures1/2_frame14.jpg
# Creating..../pictures1/2_frame15.jpg
# Creating..../pictures1/2_frame16.jpg
# Creating..../pictures1/2_frame17.jpg
# Creating..../pictures1/2_frame18.jpg
# Creating..../pictures1/2_frame19.jpg
# Creating..../pictures1/2_frame20.jpg
# Creating..../pictures1/2_frame21.jpg
# Creating..../pictures1/2_frame22.jpg
# Creating..../pictures1/2_frame23.jpg
# Creating..../pictures1/2_frame24.jpg
# ...
